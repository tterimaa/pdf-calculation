# %% [markdown]
# # Land stress impact factors for annual & permanent crops (average)
# This category includes mix of annual and permanent crops.
#
# Exiobase categories:
# - Cropland – Cereal grains nec Cropland
# – Crops nec
# - Cropland – Oil seeds
# - Cropland – Paddy rice
# - Cropland – Plant-based fibers
# - Cropland – Sugar cane, sugar beet
# - Cropland – Vegetables, fruit, nuts
# - Cropland – Wheat
#
# LC-Impact stressors
# - Annual crops
# - Permanent crops

# %%
# import required libraries
import pymrio
import numpy as np
import pandas as pd
import pycountry as pyc

# %%
# exiobase 2011 is used for calculating share of stressor for each region-product pair
exio3_11 = pymrio.parse_exiobase3(path="/Users/tterimaa/code/projects/impact-factors/IOT_2011_pxp.zip")
# exiobase 2019 is used for impact factors
exio3_19 = pymrio.parse_exiobase3(path="/Users/tterimaa/code/projects/impact-factors/IOT_2019_pxp")

# %% [markdown]
# ## Calculate DRorigin
# DRorigin is a matrix which describes the amount of the driver of biodiversity loss (DR) that occurs in impact region i sector k and is driven by consumption in region j sector k.
#
# To calculate the matrix we need to
# 1. Aggregate relevant drivers from exiobase together
# 2. Diagonalize the aggregated driver and re-calculate the IO system

# %%
# aggregate relevant drivers
groups = exio3_11.satellite.get_index(
    as_dict=True,
    grouping_pattern={
        "Cropland - Cereal grains nec Cropland": "Land stress - annual and permanent",
        "Crops nec": "Land stress - annual and permanent",
        "Cropland - Oil seeds": "Land stress - annual and permanent",
        "Cropland - Paddy rice": "Land stress - annual and permanent",
        "Cropland - Plant-based fibers": "Land stress - annual and permanent",
        "Cropland - Sugar cane, sugar beet": "Land stress - annual and permanent",
        "Cropland - Vegetables, fruit, nuts": "Land stress - annual and permanent",
        "Cropland - Wheat": "Land stress - annual and permanent",
    }
)

exio3_11.satellite_agg = exio3_11.satellite.copy(new_name="Aggregated land stress - annual and permanent")

for df_name, df in zip(exio3_11.satellite_agg.get_DataFrame(data=False, with_unit=True, with_population=False),
exio3_11.satellite_agg.get_DataFrame(data=True, with_unit=True, with_population=False)):
    if df_name == "unit":
        exio3_11.satellite_agg.__dict__[df_name] = df.groupby(groups).apply(lambda x: " & ".join(x.unit.unique()))
    else:
        exio3_11.satellite_agg.__dict__[df_name] = df.groupby(groups).sum()

# %%
# diagonalize and calculate land stress - annual and permanent 
et1_diag = exio3_11.satellite_agg.diag_stressor(("Land stress - annual and permanent"))
exio3_11.et1_diag = et1_diag
exio3_11.calc_all()
# Out:
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:984: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_cba.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:993: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_pba.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:1001: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_imp_reg = self.D_imp.groupby(
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:1007: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_exp_reg = self.D_exp.groupby(

# %%
exio3_11.et1_diag.D_cba # consumption based distribution of the driver
# Out:
# region                                                              AT  \
# sector                                                      Paddy rice
# region sector
# AT     Paddy rice                                         0.000000e+00
#        Wheat                                              1.660149e-06
#        Cereal grains nec                                  0.000000e+00
#        Vegetables, fruit, nuts                            7.685572e-08
#        Oil seeds                                          6.397305e-07
# ...                                                                ...
# WM     Membership organisation services n.e.c. (91)       0.000000e+00
#        Recreational, cultural and sporting services (92)  0.000000e+00
#        Other services (93)                                0.000000e+00
#        Private households with employed persons (95)      0.000000e+00
#        Extra-territorial organizations and bodies         0.000000e+00
#
# region                                                                \
# sector                                                         Wheat
# region sector
# AT     Paddy rice                                           0.000000
#        Wheat                                              157.898074
#        Cereal grains nec                                    0.000000
#        Vegetables, fruit, nuts                              0.000330
#        Oil seeds                                            0.001602
# ...                                                              ...
# WM     Membership organisation services n.e.c. (91)         0.000000
#        Recreational, cultural and sporting services (92)    0.000000
#        Other services (93)                                  0.000000
#        Private households with employed persons (95)        0.000000
#        Extra-territorial organizations and bodies           0.000000
#
# region                                                                      \
# sector                                                   Cereal grains nec
# region sector
# AT     Paddy rice                                                 0.000000
#        Wheat                                                      0.021678
#        Cereal grains nec                                          0.000000
#        Vegetables, fruit, nuts                                    0.001935
#        Oil seeds                                                  0.007936
# ...                                                                    ...
# WM     Membership organisation services n.e.c. (91)               0.000000
#        Recreational, cultural and sporting services (92)          0.000000
#        Other services (93)                                        0.000000
#        Private households with employed persons (95)              0.000000
#        Extra-territorial organizations and bodies                 0.000000
#
# region                                                                            \
# sector                                                   Vegetables, fruit, nuts
# region sector
# AT     Paddy rice                                                       0.000000
#        Wheat                                                            0.187834
#        Cereal grains nec                                                0.000000
#        Vegetables, fruit, nuts                                        869.905350
#        Oil seeds                                                        0.055476
# ...                                                                          ...
# WM     Membership organisation services n.e.c. (91)                     0.000000
#        Recreational, cultural and sporting services (92)                0.000000
#        Other services (93)                                              0.000000
#        Private households with employed persons (95)                    0.000000
#        Extra-territorial organizations and bodies                       0.000000
#
# region                                                               \
# sector                                                    Oil seeds
# region sector
# AT     Paddy rice                                          0.000000
#        Wheat                                               0.002623
#        Cereal grains nec                                   0.000000
#        Vegetables, fruit, nuts                             0.000216
#        Oil seeds                                          16.944944
# ...                                                             ...
# WM     Membership organisation services n.e.c. (91)        0.000000
#        Recreational, cultural and sporting services (92)   0.000000
#        Other services (93)                                 0.000000
#        Private households with employed persons (95)       0.000000
#        Extra-territorial organizations and bodies          0.000000
#
# region                                                                           \
# sector                                                   Sugar cane, sugar beet
# region sector
# AT     Paddy rice                                                      0.000000
#        Wheat                                                           0.000587
#        Cereal grains nec                                               0.000000
#        Vegetables, fruit, nuts                                         0.000049
#        Oil seeds                                                       0.000190
# ...                                                                         ...
# WM     Membership organisation services n.e.c. (91)                    0.000000
#        Recreational, cultural and sporting services (92)               0.000000
#        Other services (93)                                             0.000000
#        Private households with employed persons (95)                   0.000000
#        Extra-territorial organizations and bodies                      0.000000
#
# region                                                                       \
# sector                                                   Plant-based fibers
# region sector
# AT     Paddy rice                                                  0.000000
#        Wheat                                                       0.000150
#        Cereal grains nec                                           0.000000
#        Vegetables, fruit, nuts                                     0.000018
#        Oil seeds                                                   0.000080
# ...                                                                     ...
# WM     Membership organisation services n.e.c. (91)                0.000000
#        Recreational, cultural and sporting services (92)           0.000000
#        Other services (93)                                         0.000000
#        Private households with employed persons (95)               0.000000
#        Extra-territorial organizations and bodies                  0.000000
#
# region                                                                        \
# sector                                                   Crops nec    Cattle
# region sector
# AT     Paddy rice                                         0.000000  0.000000
#        Wheat                                              0.000257  0.662047
#        Cereal grains nec                                  0.000000  0.000000
#        Vegetables, fruit, nuts                            0.000032  0.046975
#        Oil seeds                                          0.000171  0.056919
# ...                                                            ...       ...
# WM     Membership organisation services n.e.c. (91)       0.000000  0.000000
#        Recreational, cultural and sporting services (92)  0.000000  0.000000
#        Other services (93)                                0.000000  0.000000
#        Private households with employed persons (95)      0.000000  0.000000
#        Extra-territorial organizations and bodies         0.000000  0.000000
#
# region                                                              ...  \
# sector                                                        Pigs  ...
# region sector                                                       ...
# AT     Paddy rice                                         0.000000  ...
#        Wheat                                              9.565067  ...
#        Cereal grains nec                                  0.000000  ...
#        Vegetables, fruit, nuts                            0.707209  ...
#        Oil seeds                                          0.499320  ...
# ...                                                            ...  ...
# WM     Membership organisation services n.e.c. (91)       0.000000  ...
#        Recreational, cultural and sporting services (92)  0.000000  ...
#        Other services (93)                                0.000000  ...
#        Private households with employed persons (95)      0.000000  ...
#        Extra-territorial organizations and bodies         0.000000  ...
#
# region                                                                              WM  \
# sector                                                   Paper for treatment: landfill
# region sector
# AT     Paddy rice                                                             0.000000
#        Wheat                                                                  0.031539
#        Cereal grains nec                                                      0.000000
#        Vegetables, fruit, nuts                                                0.002032
#        Oil seeds                                                              0.009636
# ...                                                                                ...
# WM     Membership organisation services n.e.c. (91)                           0.000000
#        Recreational, cultural and sporting services (92)                      0.000000
#        Other services (93)                                                    0.000000
#        Private households with employed persons (95)                          0.000000
#        Extra-territorial organizations and bodies                             0.000000
#
# region                                                                                          \
# sector                                                   Plastic waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                     0.000000
#        Wheat                                                                          0.019111
#        Cereal grains nec                                                              0.000000
#        Vegetables, fruit, nuts                                                        0.000842
#        Oil seeds                                                                      0.006046
# ...                                                                                        ...
# WM     Membership organisation services n.e.c. (91)                                   0.000000
#        Recreational, cultural and sporting services (92)                              0.000000
#        Other services (93)                                                            0.000000
#        Private households with employed persons (95)                                  0.000000
#        Extra-territorial organizations and bodies                                     0.000000
#
# region                                                                                                        \
# sector                                                   Inert/metal/hazardous waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                                  0.000000
#        Wheat                                                                                       0.027544
#        Cereal grains nec                                                                           0.000000
#        Vegetables, fruit, nuts                                                                     0.001837
#        Oil seeds                                                                                   0.008633
# ...                                                                                                     ...
# WM     Membership organisation services n.e.c. (91)                                                0.000000
#        Recreational, cultural and sporting services (92)                                           0.000000
#        Other services (93)                                                                         0.000000
#        Private households with employed persons (95)                                               0.000000
#        Extra-territorial organizations and bodies                                                  0.000000
#
# region                                                                                           \
# sector                                                   Textiles waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                      0.000000
#        Wheat                                                                           0.005076
#        Cereal grains nec                                                               0.000000
#        Vegetables, fruit, nuts                                                         0.000241
#        Oil seeds                                                                       0.002268
# ...                                                                                         ...
# WM     Membership organisation services n.e.c. (91)                                    0.000000
#        Recreational, cultural and sporting services (92)                               0.000000
#        Other services (93)                                                             0.000000
#        Private households with employed persons (95)                                   0.000000
#        Extra-territorial organizations and bodies                                      0.000000
#
# region                                                                                       \
# sector                                                   Wood waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                  0.000000
#        Wheat                                                                       0.007291
#        Cereal grains nec                                                           0.000000
#        Vegetables, fruit, nuts                                                     0.000356
#        Oil seeds                                                                   0.002896
# ...                                                                                     ...
# WM     Membership organisation services n.e.c. (91)                                0.000000
#        Recreational, cultural and sporting services (92)                           0.000000
#        Other services (93)                                                         0.000000
#        Private households with employed persons (95)                               0.000000
#        Extra-territorial organizations and bodies                                  0.000000
#
# region                                                                                                 \
# sector                                                   Membership organisation services n.e.c. (91)
# region sector
# AT     Paddy rice                                                                            0.000000
#        Wheat                                                                                 0.331737
#        Cereal grains nec                                                                     0.000000
#        Vegetables, fruit, nuts                                                               0.011566
#        Oil seeds                                                                             0.054866
# ...                                                                                               ...
# WM     Membership organisation services n.e.c. (91)                                          0.000000
#        Recreational, cultural and sporting services (92)                                     0.000000
#        Other services (93)                                                                   0.000000
#        Private households with employed persons (95)                                         0.000000
#        Extra-territorial organizations and bodies                                            0.000000
#
# region                                                                                                      \
# sector                                                   Recreational, cultural and sporting services (92)
# region sector
# AT     Paddy rice                                                                                 0.000000
#        Wheat                                                                                      0.582074
#        Cereal grains nec                                                                          0.000000
#        Vegetables, fruit, nuts                                                                    0.042418
#        Oil seeds                                                                                  0.181045
# ...                                                                                                    ...
# WM     Membership organisation services n.e.c. (91)                                               0.000000
#        Recreational, cultural and sporting services (92)                                          0.000000
#        Other services (93)                                                                        0.000000
#        Private households with employed persons (95)                                              0.000000
#        Extra-territorial organizations and bodies                                                 0.000000
#
# region                                                                        \
# sector                                                   Other services (93)
# region sector
# AT     Paddy rice                                                   0.000000
#        Wheat                                                        0.655705
#        Cereal grains nec                                            0.000000
#        Vegetables, fruit, nuts                                      0.033022
#        Oil seeds                                                    0.153270
# ...                                                                      ...
# WM     Membership organisation services n.e.c. (91)                 0.000000
#        Recreational, cultural and sporting services (92)            0.000000
#        Other services (93)                                          0.000000
#        Private households with employed persons (95)                0.000000
#        Extra-territorial organizations and bodies                   0.000000
#
# region                                                                                                  \
# sector                                                   Private households with employed persons (95)
# region sector
# AT     Paddy rice                                                                             0.000000
#        Wheat                                                                                  0.009160
#        Cereal grains nec                                                                      0.000000
#        Vegetables, fruit, nuts                                                                0.000530
#        Oil seeds                                                                              0.002944
# ...                                                                                                ...
# WM     Membership organisation services n.e.c. (91)                                           0.000000
#        Recreational, cultural and sporting services (92)                                      0.000000
#        Other services (93)                                                                    0.000000
#        Private households with employed persons (95)                                          0.000000
#        Extra-territorial organizations and bodies                                             0.000000
#
# region
# sector                                                   Extra-territorial organizations and bodies
# region sector
# AT     Paddy rice                                                                               0.0
#        Wheat                                                                                    0.0
#        Cereal grains nec                                                                        0.0
#        Vegetables, fruit, nuts                                                                  0.0
#        Oil seeds                                                                                0.0
# ...                                                                                             ...
# WM     Membership organisation services n.e.c. (91)                                             0.0
#        Recreational, cultural and sporting services (92)                                        0.0
#        Other services (93)                                                                      0.0
#        Private households with employed persons (95)                                            0.0
#        Extra-territorial organizations and bodies                                               0.0
#
# [9800 rows x 9800 columns]

# %% [markdown]
# ## Calculate DR share
# DR share is a new matrix that represents the share of the driver in the impact region i from the total amount of driver that is driven by consumption in region j sector k.
#
# To calculate the matrix each column of DR origin is shared by the sum of that column.

# %%
# calculate dr_s - share of the driver of biodiversity loss in impact region i from the total amount of the driver that is driven by consumption in consumption region j, product sector k
columns = {}
for series_name, series in exio3_11.et1_diag.D_cba.items():
    series_sum = series.sum()
    columns[series_name] = series / series_sum

dr_s = pd.DataFrame(columns)
dr_s
# Out:
#                                                                     AT  \
#                                                             Paddy rice
# region sector
# AT     Paddy rice                                         0.000000e+00
#        Wheat                                              2.734542e-07
#        Cereal grains nec                                  0.000000e+00
#        Vegetables, fruit, nuts                            1.265942e-08
#        Oil seeds                                          1.053743e-07
# ...                                                                ...
# WM     Membership organisation services n.e.c. (91)       0.000000e+00
#        Recreational, cultural and sporting services (92)  0.000000e+00
#        Other services (93)                                0.000000e+00
#        Private households with employed persons (95)      0.000000e+00
#        Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                         \
#                                                                  Wheat
# region sector
# AT     Paddy rice                                         0.000000e+00
#        Wheat                                              2.003626e-01
#        Cereal grains nec                                  0.000000e+00
#        Vegetables, fruit, nuts                            4.187797e-07
#        Oil seeds                                          2.032239e-06
# ...                                                                ...
# WM     Membership organisation services n.e.c. (91)       0.000000e+00
#        Recreational, cultural and sporting services (92)  0.000000e+00
#        Other services (93)                                0.000000e+00
#        Private households with employed persons (95)      0.000000e+00
#        Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                             \
#                                                          Cereal grains nec
# region sector
# AT     Paddy rice                                                 0.000000
#        Wheat                                                      0.001964
#        Cereal grains nec                                          0.000000
#        Vegetables, fruit, nuts                                    0.000175
#        Oil seeds                                                  0.000719
# ...                                                                    ...
# WM     Membership organisation services n.e.c. (91)               0.000000
#        Recreational, cultural and sporting services (92)          0.000000
#        Other services (93)                                        0.000000
#        Private households with employed persons (95)              0.000000
#        Extra-territorial organizations and bodies                 0.000000
#
#                                                                                   \
#                                                          Vegetables, fruit, nuts
# region sector
# AT     Paddy rice                                                       0.000000
#        Wheat                                                            0.000057
#        Cereal grains nec                                                0.000000
#        Vegetables, fruit, nuts                                          0.263189
#        Oil seeds                                                        0.000017
# ...                                                                          ...
# WM     Membership organisation services n.e.c. (91)                     0.000000
#        Recreational, cultural and sporting services (92)                0.000000
#        Other services (93)                                              0.000000
#        Private households with employed persons (95)                    0.000000
#        Extra-territorial organizations and bodies                       0.000000
#
#                                                                         \
#                                                              Oil seeds
# region sector
# AT     Paddy rice                                         0.000000e+00
#        Wheat                                              1.406819e-06
#        Cereal grains nec                                  0.000000e+00
#        Vegetables, fruit, nuts                            1.156109e-07
#        Oil seeds                                          9.088465e-03
# ...                                                                ...
# WM     Membership organisation services n.e.c. (91)       0.000000e+00
#        Recreational, cultural and sporting services (92)  0.000000e+00
#        Other services (93)                                0.000000e+00
#        Private households with employed persons (95)      0.000000e+00
#        Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                                  \
#                                                          Sugar cane, sugar beet
# region sector
# AT     Paddy rice                                                      0.000000
#        Wheat                                                           0.000034
#        Cereal grains nec                                               0.000000
#        Vegetables, fruit, nuts                                         0.000003
#        Oil seeds                                                       0.000011
# ...                                                                         ...
# WM     Membership organisation services n.e.c. (91)                    0.000000
#        Recreational, cultural and sporting services (92)               0.000000
#        Other services (93)                                             0.000000
#        Private households with employed persons (95)                   0.000000
#        Extra-territorial organizations and bodies                      0.000000
#
#                                                                              \
#                                                          Plant-based fibers
# region sector
# AT     Paddy rice                                              0.000000e+00
#        Wheat                                                   2.428886e-06
#        Cereal grains nec                                       0.000000e+00
#        Vegetables, fruit, nuts                                 2.885386e-07
#        Oil seeds                                               1.298876e-06
# ...                                                                     ...
# WM     Membership organisation services n.e.c. (91)            0.000000e+00
#        Recreational, cultural and sporting services (92)       0.000000e+00
#        Other services (93)                                     0.000000e+00
#        Private households with employed persons (95)           0.000000e+00
#        Extra-territorial organizations and bodies              0.000000e+00
#
#                                                                               \
#                                                          Crops nec    Cattle
# region sector
# AT     Paddy rice                                         0.000000  0.000000
#        Wheat                                              0.000079  0.025444
#        Cereal grains nec                                  0.000000  0.000000
#        Vegetables, fruit, nuts                            0.000010  0.001805
#        Oil seeds                                          0.000053  0.002188
# ...                                                            ...       ...
# WM     Membership organisation services n.e.c. (91)       0.000000  0.000000
#        Recreational, cultural and sporting services (92)  0.000000  0.000000
#        Other services (93)                                0.000000  0.000000
#        Private households with employed persons (95)      0.000000  0.000000
#        Extra-territorial organizations and bodies         0.000000  0.000000
#
#                                                                     ...  \
#                                                               Pigs  ...
# region sector                                                       ...
# AT     Paddy rice                                         0.000000  ...
#        Wheat                                              0.252813  ...
#        Cereal grains nec                                  0.000000  ...
#        Vegetables, fruit, nuts                            0.018692  ...
#        Oil seeds                                          0.013197  ...
# ...                                                            ...  ...
# WM     Membership organisation services n.e.c. (91)       0.000000  ...
#        Recreational, cultural and sporting services (92)  0.000000  ...
#        Other services (93)                                0.000000  ...
#        Private households with employed persons (95)      0.000000  ...
#        Extra-territorial organizations and bodies         0.000000  ...
#
#                                                                                     WM  \
#                                                          Paper for treatment: landfill
# region sector
# AT     Paddy rice                                                             0.000000
#        Wheat                                                                  0.000078
#        Cereal grains nec                                                      0.000000
#        Vegetables, fruit, nuts                                                0.000005
#        Oil seeds                                                              0.000024
# ...                                                                                ...
# WM     Membership organisation services n.e.c. (91)                           0.000000
#        Recreational, cultural and sporting services (92)                      0.000000
#        Other services (93)                                                    0.000000
#        Private households with employed persons (95)                          0.000000
#        Extra-territorial organizations and bodies                             0.000000
#
#                                                                                                 \
#                                                          Plastic waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                     0.000000
#        Wheat                                                                          0.000071
#        Cereal grains nec                                                              0.000000
#        Vegetables, fruit, nuts                                                        0.000003
#        Oil seeds                                                                      0.000022
# ...                                                                                        ...
# WM     Membership organisation services n.e.c. (91)                                   0.000000
#        Recreational, cultural and sporting services (92)                              0.000000
#        Other services (93)                                                            0.000000
#        Private households with employed persons (95)                                  0.000000
#        Extra-territorial organizations and bodies                                     0.000000
#
#                                                                                                               \
#                                                          Inert/metal/hazardous waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                                  0.000000
#        Wheat                                                                                       0.000078
#        Cereal grains nec                                                                           0.000000
#        Vegetables, fruit, nuts                                                                     0.000005
#        Oil seeds                                                                                   0.000024
# ...                                                                                                     ...
# WM     Membership organisation services n.e.c. (91)                                                0.000000
#        Recreational, cultural and sporting services (92)                                           0.000000
#        Other services (93)                                                                         0.000000
#        Private households with employed persons (95)                                               0.000000
#        Extra-territorial organizations and bodies                                                  0.000000
#
#                                                                                                  \
#                                                          Textiles waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                      0.000000
#        Wheat                                                                           0.000085
#        Cereal grains nec                                                               0.000000
#        Vegetables, fruit, nuts                                                         0.000004
#        Oil seeds                                                                       0.000038
# ...                                                                                         ...
# WM     Membership organisation services n.e.c. (91)                                    0.000000
#        Recreational, cultural and sporting services (92)                               0.000000
#        Other services (93)                                                             0.000000
#        Private households with employed persons (95)                                   0.000000
#        Extra-territorial organizations and bodies                                      0.000000
#
#                                                                                              \
#                                                          Wood waste for treatment: landfill
# region sector
# AT     Paddy rice                                                                  0.000000
#        Wheat                                                                       0.000082
#        Cereal grains nec                                                           0.000000
#        Vegetables, fruit, nuts                                                     0.000004
#        Oil seeds                                                                   0.000032
# ...                                                                                     ...
# WM     Membership organisation services n.e.c. (91)                                0.000000
#        Recreational, cultural and sporting services (92)                           0.000000
#        Other services (93)                                                         0.000000
#        Private households with employed persons (95)                               0.000000
#        Extra-territorial organizations and bodies                                  0.000000
#
#                                                                                                        \
#                                                          Membership organisation services n.e.c. (91)
# region sector
# AT     Paddy rice                                                                            0.000000
#        Wheat                                                                                 0.000114
#        Cereal grains nec                                                                     0.000000
#        Vegetables, fruit, nuts                                                               0.000004
#        Oil seeds                                                                             0.000019
# ...                                                                                               ...
# WM     Membership organisation services n.e.c. (91)                                          0.000000
#        Recreational, cultural and sporting services (92)                                     0.000000
#        Other services (93)                                                                   0.000000
#        Private households with employed persons (95)                                         0.000000
#        Extra-territorial organizations and bodies                                            0.000000
#
#                                                                                                             \
#                                                          Recreational, cultural and sporting services (92)
# region sector
# AT     Paddy rice                                                                                 0.000000
#        Wheat                                                                                      0.000121
#        Cereal grains nec                                                                          0.000000
#        Vegetables, fruit, nuts                                                                    0.000009
#        Oil seeds                                                                                  0.000038
# ...                                                                                                    ...
# WM     Membership organisation services n.e.c. (91)                                               0.000000
#        Recreational, cultural and sporting services (92)                                          0.000000
#        Other services (93)                                                                        0.000000
#        Private households with employed persons (95)                                              0.000000
#        Extra-territorial organizations and bodies                                                 0.000000
#
#                                                                               \
#                                                          Other services (93)
# region sector
# AT     Paddy rice                                                   0.000000
#        Wheat                                                        0.000102
#        Cereal grains nec                                            0.000000
#        Vegetables, fruit, nuts                                      0.000005
#        Oil seeds                                                    0.000024
# ...                                                                      ...
# WM     Membership organisation services n.e.c. (91)                 0.000000
#        Recreational, cultural and sporting services (92)            0.000000
#        Other services (93)                                          0.000000
#        Private households with employed persons (95)                0.000000
#        Extra-territorial organizations and bodies                   0.000000
#
#                                                                                                         \
#                                                          Private households with employed persons (95)
# region sector
# AT     Paddy rice                                                                             0.000000
#        Wheat                                                                                  0.000083
#        Cereal grains nec                                                                      0.000000
#        Vegetables, fruit, nuts                                                                0.000005
#        Oil seeds                                                                              0.000027
# ...                                                                                                ...
# WM     Membership organisation services n.e.c. (91)                                           0.000000
#        Recreational, cultural and sporting services (92)                                      0.000000
#        Other services (93)                                                                    0.000000
#        Private households with employed persons (95)                                          0.000000
#        Extra-territorial organizations and bodies                                             0.000000
#
#
#                                                          Extra-territorial organizations and bodies
# region sector
# AT     Paddy rice                                                                               NaN
#        Wheat                                                                                    NaN
#        Cereal grains nec                                                                        NaN
#        Vegetables, fruit, nuts                                                                  NaN
#        Oil seeds                                                                                NaN
# ...                                                                                             ...
# WM     Membership organisation services n.e.c. (91)                                             NaN
#        Recreational, cultural and sporting services (92)                                        NaN
#        Other services (93)                                                                      NaN
#        Private households with employed persons (95)                                            NaN
#        Extra-territorial organizations and bodies                                               NaN
#
# [9800 rows x 9800 columns]

# %% [markdown]
# ## Calculate DR unit
# DR unit is a region harmonized version of DR share.
#
# To calculate DR unit we need to:
# 1. Identify regions that are missing from exiobase (rest of the world regions) but are present in lc-impact.
# 2. Assume that the impacts are divided evenly across the rest of the world category
# 3. By that assumption we can add the missing countries to DR share as the impact of the row region where country belongs to divided by the number of countries in that region

# %%
# harmonize regions 

# for this harmonization we need to know which countries go into:
# 1. rest of the world europe
# 2. rest of the world asia pacific
# 3. rest of the world middle east
# 4. rest of the world africa
# 5. rest of the world americas

row_eu_countries = {
    'AL': 'Albania',
    'AD': 'Andorra',
    'AZ': 'Azerbaijan',
    'BA': 'Bosnia and Herzegovina',
    'BY': 'Belarus',
    'FO': 'Faroe Islands',
    'GI': 'Gibraltar',
    'GG': 'Guernsey',
    'IS': 'Iceland',
    'IM': 'Isle of Man',
    'JE': 'Jersey',
    'GL': 'Greenland',
    'LI': 'Liechtenstein',
    'SM': 'San Marino',
    'MC': 'Monaco',
    'GE': 'Georgia',
    'MK': 'Macedonia',
    'MD': 'Moldova',
    'ME': 'Montenegro',
    'RS': 'Serbia',
    'UA': 'Ukraine',
    # overseas territories of EU countries 
    'GP': 'Guadeloupe',
    'PF': 'French Polynesia',
    'FK': 'Falkland Islands (Islas Malvinas)',
    'GF': 'French Guiana',
    'VG': 'Virgin Islands',
    'RE': 'Reunion',
    'VC': 'Saint Vincent and the Grenadines',
}

row_asia_pacific_countries = {
    'AS': 'American Samoa', 'BD': 'Bangladesh', 'BN': 'Brunei', 'BT': 'Bhutan', 'CK': 'Cook Islands', 'CX': 'Christmas Island',
    'KH': 'Cambodia', 'FJ': 'Fiji', 'GU': 'Guam', 'IO': 'British Indian Ocean Territory (the)',
    'KZ': 'Kazakhstan', 'KI': 'Kiribati', 'KG': 'Kyrgyzstan', 'LA': 'Laos', 'MY': 'Malaysia', 'MH': 'Marshall Islands', 'MP': 'Northern Mariana Islands', 'MV': 'Maldives',
    'MN': 'Mongolia', 'MM': 'Myanmar (Burma)', 'NF': 'Norfolk Island', 'NP': 'Nepal', 'NC': 'New Caledonia', 'NZ': 'New Zealand',
    'KP': 'North Korea', 'PW': 'Palau', 'PK': 'Pakistan', 'PG': 'Papua New Guinea', 'PH': 'Philippines', 'PN': 'Pitcairn',
    'WS': 'Samoa', 'SB': 'Solomon Islands', 'LK': 'Sri Lanka', 'SG': 'Singapore',
    'TJ': 'Tajikistan', 'TH': 'Thailand', 'TO': 'Tonga', 'TM': 'Turkmenistan', 'TL': 'Timor-Leste', 'TV': 'Tuvalu', 'WF': 'Wallis and Futuna', 'TF': 'French Southern Territories (the)',
    'UM': 'United States Minor Outlying Islands', 'UZ': 'Uzbekistan', 'VU': 'Vanuatu', 'VN': 'Vietnam'
}

row_african_countries = {
    'DZ': 'Algeria', 'AO': 'Angola', 'BJ': 'Benin', 'BW': 'Botswana', 'BF': 'Burkina Faso', 'BI': 'Burundi',
    'CM': 'Cameroon', 'CV': 'Cape Verde', 'CF': 'Central African Republic', 'TD': 'Chad', 'KM': 'Comoros',
    'CG': 'Congo', 'CD': 'Congo DRC', 'DJ': 'Djibouti', 'EG': 'Egypt', 'GQ': 'Equatorial Guinea', 'ER': 'Eritrea',
    'ET': 'Ethiopia', 'GA': 'Gabon', 'GM': 'Gambia, The', 'GH': 'Ghana', 'GN': 'Guinea', 'GW': 'Guinea-Bissau', 'HM': 'Heard Island and McDonald Islands',
    'CI': 'Ivory Coast', 'KE': 'Kenya', 'KY': 'Cayman Islands', 'LS': 'Lesotho', 'LR': 'Liberia', 'LY': 'Libya', 'MG': 'Madagascar',
    'MW': 'Malawi', 'ML': 'Mali', 'MR': 'Mauritania', 'MU': 'Mauritius', 'MA': 'Morocco', 'MZ': 'Mozambique', 'MQ': 'Martinique',
    'NA': 'Namibia', 'NE': 'Niger', 'NG': 'Nigeria', 'RW': 'Rwanda', 'ST': 'São Tomé and Príncipe', 'SN': 'Senegal',
    'SL': 'Sierra Leone', 'SO': 'Somalia', 'SZ': 'Eswatini', 'SC': 'Seychelles', 'SS': 'South Sudan',
    'SD': 'Sudan', 'TZ': 'Tanzania', 'TG': 'Togo', 'TN': 'Tunisia', 'UG': 'Uganda', 'YT': 'Mayotte', 'ZM': 'Zambia', 'ZW': 'Zimbabwe'
}

row_american_countries = {
    'AQ': 'Antarctica', 'AI': 'Anguilla', 'AG': 'Antigua and Barbuda', 'AW': 'Aruba', 'AR': 'Argentina', 'BS': 'Bahamas, The', 'BZ': 'Belize', 'BO': 'Bolivia',
    'BB': 'Barbados', 'BM': 'Bermuda', 'BV': 'Bouvet Island', 'CL': 'Chile', 'CO': 'Colombia', 'CR': 'Costa Rica', 'CU': 'Cuba', 'DO': 'Dominican Republic', 'DM': 'Dominica',
    'EC': 'Ecuador', 'SV': 'El Salvador', 'GD': 'Grenada', 'GT': 'Guatemala', 'GY': 'Guyana', 'HT': 'Haiti', 'HN': 'Honduras', 'JM': 'Jamaica',
    'MS': 'Montserrat', 'NI': 'Nicaragua', 'PA': 'Panama', 'PY': 'Paraguay', 'PE': 'Peru', 'PR': 'Puerto Rico', 'KN': 'Saint Kitts and Nevis', 'LC': 'Saint Lucia',
    'SR': 'Suriname', 'TC': 'Turks and Caicos Islands', 'TT': 'Trinidad and Tobago', 'UY': 'Uruguay', 'VE': 'Venezuela', 'VI': 'United States Virgin Islands'
}

row_middle_eastern_countries = {
    'AF': 'Afghanistan', 'AM': 'Armenia', 'BH': 'Bahrain',
    'IR': 'Iran', 'IQ': 'Iraq', 'IL': 'Israel', 'JO': 'Jordan', 'KW': 'Kuwait', 'LB': 'Lebanon', 'OM': 'Oman',
    'QA': 'Qatar', 'SA': 'Saudi Arabia', 'SY': 'Syria', 'AE': 'United Arab Emirates',
    'YE': 'Yemen'
}

exio_regions = exio3_11.get_regions()
row_regions = {
    "WA": "Asia and pacific",
    "WE": "Europe",
    "WF": "Africa",
    "WM": "Middle east",
    "WL": "America"
}

# harmonize regions between lc-impact and exiobase
all_row_region_keys = list(row_eu_countries.keys()) + list(row_asia_pacific_countries.keys()) + list(row_african_countries.keys()) + list(row_american_countries.keys()) + list(row_middle_eastern_countries.keys())
exio_regions_without_row = [region for region in exio_regions if region not in row_regions.keys()]
print(len(exio_regions_without_row)) # exiobase contains 44 exact regions + 5 row regions

# combine exact regions from exiobase with exact row regions
all_regions = list(all_row_region_keys) + list(exio_regions_without_row)
print("Regions: ", len(all_regions))
print("Unique regions: ", len(set(all_regions)))
assert len(all_regions) == len(set(all_regions)), "There are duplicate regions in the all_regions list"
# Out:
# 44
# Regions:  229
# Unique regions:  229

# %%
# prepare lc-impact
lci = pd.read_excel("/Users/tterimaa/code/projects/impact-factors/lc-impact/LC-Impact/11-Land stress/CFs_land_Use_average.xlsx", sheet_name="occupation average country", skiprows=1, header=[0,1])
# Flatten the multi-level columns and rename them
lci.columns = [' '.join(col).strip() for col in lci.columns]
# rename first column to Country
lci.rename(columns={lci.columns[0]: "Country"}, inplace=True)
lci = lci[["Country", "Annual crops Median", "Permanent crops Median"]]
# Calculate the mean of only the "Annual crops median" and "Permanent crops median" columns
lci["Average"] = lci[["Annual crops Median", "Permanent crops Median"]].mean(axis=1)
lci
# Out:
#                Country  Annual crops Median  Permanent crops Median  \
# 0          Afghanistan         5.566453e-16            3.447819e-16
# 1              Albania         5.976012e-15            3.409073e-15
# 2              Algeria         3.094926e-16            1.856075e-16
# 3       American Samoa         1.334275e-13            1.191927e-13
# 4              Andorra         2.807275e-15            1.806190e-15
# ..                 ...                  ...                     ...
# 239            Vietnam         5.988875e-15            4.463550e-15
# 240  Wallis and Futuna         2.007363e-14            1.426736e-14
# 241              Yemen         1.005630e-15            8.422026e-16
# 242             Zambia         8.055880e-16            6.295117e-16
# 243           Zimbabwe         1.008586e-15            7.009162e-16
#
#           Average
# 0    4.507136e-16
# 1    4.692543e-15
# 2    2.475501e-16
# 3    1.263101e-13
# 4    2.306733e-15
# ..            ...
# 239  5.226213e-15
# 240  1.717050e-14
# 241  9.239165e-16
# 242  7.175499e-16
# 243  8.547510e-16
#
# [244 rows x 4 columns]

# %%
# Function to convert country name to ISO Alpha-2 code
def get_country_code(name):
    try:
        return pyc.countries.lookup(name).alpha_2
    except LookupError:
        try:
            return extra_mappings[name]
        except LookupError:
            print("Country code not found for ", name)
            return None  # Return None if country not found

extra_mappings = {
    "Turkey": "TR",
    "Russia": "RU",
    "Bahamas, The": "BS",
    "Brunei": "BN",
    "Cape Verde": "CV",
    "Congo DRC": "CD",
    "Falkland Islands": "FK",
    "Gambia, The": "GM",
    "Ivory Coast": "CI",
    "The Former Yugoslav Republic of Macedonia": "MK",
    "Myanmar (Burma)": "MM",
    "Reunion": "RE",
    "St. Vincent and the Grenadines": "VC",
    "Svalbard": "SJ",
    "Swaziland": "SZ",
    "US Virgin Islands": "VI",
    "Western Samoa": "WS",
}

lci["Country_Code"] = lci["Country"].apply(get_country_code)
# remove rows with missing country codes
lci = lci.dropna(subset=["Country_Code"])
# taiwan is missing from lc-impact, add taiwan as new row with country code TW and asia averages
cf_annual_asia = 1.4159650959661E-15
cf_permanent_asia = 1.02741974515257E-15
cf_average_asia = (cf_annual_asia + cf_permanent_asia) / 2
row = pd.DataFrame({
    "Country": ["Taiwan"],
    "Average": [cf_average_asia],
    "Annual crops Median": [cf_annual_asia],
    "Permanent crops Median": [cf_permanent_asia],
    "Country_Code": ["TW"],
})
lci = pd.concat([lci, row], ignore_index=True)
lci.set_index("Country_Code", inplace=True)
lci
# Out:
# Country code not found for  Azores
# Country code not found for  Bonaire
# Country code not found for  Canarias
# Country code not found for  Cocos Islands
# Country code not found for  Curacao
# Country code not found for  Madeira
# Country code not found for  Micronesia
# Country code not found for  Palestinian Territory
# Country code not found for  Saba
# Country code not found for  Saint Barthelemy
# Country code not found for  Saint Eustatius
# Country code not found for  Saint Helena
# Country code not found for  Saint Martin
# Country code not found for  Sint Maarten
# Country code not found for  South Georgia
# Country code not found for  Vatican City
#                         Country  Annual crops Median  Permanent crops Median  \
# Country_Code
# AF                  Afghanistan         5.566453e-16            3.447819e-16
# AL                      Albania         5.976012e-15            3.409073e-15
# DZ                      Algeria         3.094926e-16            1.856075e-16
# AS               American Samoa         1.334275e-13            1.191927e-13
# AD                      Andorra         2.807275e-15            1.806190e-15
# ...                         ...                  ...                     ...
# WF            Wallis and Futuna         2.007363e-14            1.426736e-14
# YE                        Yemen         1.005630e-15            8.422026e-16
# ZM                       Zambia         8.055880e-16            6.295117e-16
# ZW                     Zimbabwe         1.008586e-15            7.009162e-16
# TW                       Taiwan         1.415965e-15            1.027420e-15
#
#                    Average
# Country_Code
# AF            4.507136e-16
# AL            4.692543e-15
# DZ            2.475501e-16
# AS            1.263101e-13
# AD            2.306733e-15
# ...                    ...
# WF            1.717050e-14
# YE            9.239165e-16
# ZM            7.175499e-16
# ZW            8.547510e-16
# TW            1.221692e-15
#
# [229 rows x 4 columns]

# %%
# find if some regions are missing from the lci 
missing_regions = [region for region in all_regions if region not in lci.index.unique()]
print("Missing regions (lc-impact): ", missing_regions)

# find out if some regions are missing from augmented exiobase regions 
lci_regions = lci.index
missing_from_all_regions = [region for region in lci_regions if region not in all_regions]
print("Missing regions (exiobase, augmented): ", missing_from_all_regions)

# assert that all regions in lci-water are in the all_regions list
assert sorted(lci_regions) == sorted(all_regions), "Some regions in lci-water are not in the all_regions list"
# Out:
# Missing regions (lc-impact):  []
# Missing regions (exiobase, augmented):  []

# %%
# augment dr_s to create dr_u

# new regions are calculated by dividing their corresponding row region by the number of countries in the row region
# for example, row region Argentina is sub-matrix WA divided by the number of countries in row region WA
wl = dr_s.loc["WL"].copy()
wl = wl / len(row_american_countries)

we = dr_s.loc["WE"].copy()
we = we / len(row_eu_countries)

wa = dr_s.loc["WA"].copy()
wa = wa / len(row_asia_pacific_countries)

wf = dr_s.loc["WF"].copy()
wf = wf / len(row_african_countries)

wm = dr_s.loc["WM"].copy()
wm = wm / len(row_middle_eastern_countries)

dr_u = dr_s.copy()
dr_u = dr_u.drop(index=row_regions.keys(), level='region')

# build a mapping of country codes to region dataframes
country_to_region = {}
for region in all_row_region_keys:
    if region in row_eu_countries:
        country_to_region[region] = we
    elif region in row_asia_pacific_countries:
        country_to_region[region] = wa
    elif region in row_african_countries:
        country_to_region[region] = wf
    elif region in row_american_countries:
        country_to_region[region] = wl
    elif region in row_middle_eastern_countries:
        country_to_region[region] = wm
    else:
        raise ValueError(f"Unknown region: {region}")

# add all new regions to dr_u
all_indices = []
all_data = []
for region in all_row_region_keys:
    region_data = country_to_region[region].copy()
    idx = pd.MultiIndex.from_product([[region],region_data.index], names=['region', 'sector'])
    all_indices.append(idx)
    all_data.append(region_data)

combined_idx = pd.MultiIndex.from_tuples(
    [idx for subidx in all_indices for idx in subidx]
)

combined_data = pd.concat(all_data)
combined_data.index = combined_idx

dr_u = pd.concat([dr_u, combined_data])
dr_u
# Out:
#                                                                 AT  \
#                                                         Paddy rice
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              2.734542e-07
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            1.265942e-08
#    Oil seeds                                          1.053743e-07
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                     \
#                                                              Wheat
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              2.003626e-01
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            4.187797e-07
#    Oil seeds                                          2.032239e-06
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                         \
#                                                      Cereal grains nec
# AT Paddy rice                                                 0.000000
#    Wheat                                                      0.001964
#    Cereal grains nec                                          0.000000
#    Vegetables, fruit, nuts                                    0.000175
#    Oil seeds                                                  0.000719
# ...                                                                ...
# YE Membership organisation services n.e.c. (91)               0.000000
#    Recreational, cultural and sporting services (92)          0.000000
#    Other services (93)                                        0.000000
#    Private households with employed persons (95)              0.000000
#    Extra-territorial organizations and bodies                 0.000000
#
#                                                                               \
#                                                      Vegetables, fruit, nuts
# AT Paddy rice                                                       0.000000
#    Wheat                                                            0.000057
#    Cereal grains nec                                                0.000000
#    Vegetables, fruit, nuts                                          0.263189
#    Oil seeds                                                        0.000017
# ...                                                                      ...
# YE Membership organisation services n.e.c. (91)                     0.000000
#    Recreational, cultural and sporting services (92)                0.000000
#    Other services (93)                                              0.000000
#    Private households with employed persons (95)                    0.000000
#    Extra-territorial organizations and bodies                       0.000000
#
#                                                                     \
#                                                          Oil seeds
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              1.406819e-06
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            1.156109e-07
#    Oil seeds                                          9.088465e-03
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                              \
#                                                      Sugar cane, sugar beet
# AT Paddy rice                                                      0.000000
#    Wheat                                                           0.000034
#    Cereal grains nec                                               0.000000
#    Vegetables, fruit, nuts                                         0.000003
#    Oil seeds                                                       0.000011
# ...                                                                     ...
# YE Membership organisation services n.e.c. (91)                    0.000000
#    Recreational, cultural and sporting services (92)               0.000000
#    Other services (93)                                             0.000000
#    Private households with employed persons (95)                   0.000000
#    Extra-territorial organizations and bodies                      0.000000
#
#                                                                          \
#                                                      Plant-based fibers
# AT Paddy rice                                              0.000000e+00
#    Wheat                                                   2.428886e-06
#    Cereal grains nec                                       0.000000e+00
#    Vegetables, fruit, nuts                                 2.885386e-07
#    Oil seeds                                               1.298876e-06
# ...                                                                 ...
# YE Membership organisation services n.e.c. (91)            0.000000e+00
#    Recreational, cultural and sporting services (92)       0.000000e+00
#    Other services (93)                                     0.000000e+00
#    Private households with employed persons (95)           0.000000e+00
#    Extra-territorial organizations and bodies              0.000000e+00
#
#                                                                           \
#                                                      Crops nec    Cattle
# AT Paddy rice                                         0.000000  0.000000
#    Wheat                                              0.000079  0.025444
#    Cereal grains nec                                  0.000000  0.000000
#    Vegetables, fruit, nuts                            0.000010  0.001805
#    Oil seeds                                          0.000053  0.002188
# ...                                                        ...       ...
# YE Membership organisation services n.e.c. (91)       0.000000  0.000000
#    Recreational, cultural and sporting services (92)  0.000000  0.000000
#    Other services (93)                                0.000000  0.000000
#    Private households with employed persons (95)      0.000000  0.000000
#    Extra-territorial organizations and bodies         0.000000  0.000000
#
#                                                                 ...  \
#                                                           Pigs  ...
# AT Paddy rice                                         0.000000  ...
#    Wheat                                              0.252813  ...
#    Cereal grains nec                                  0.000000  ...
#    Vegetables, fruit, nuts                            0.018692  ...
#    Oil seeds                                          0.013197  ...
# ...                                                        ...  ...
# YE Membership organisation services n.e.c. (91)       0.000000  ...
#    Recreational, cultural and sporting services (92)  0.000000  ...
#    Other services (93)                                0.000000  ...
#    Private households with employed persons (95)      0.000000  ...
#    Extra-territorial organizations and bodies         0.000000  ...
#
#                                                                                 WM  \
#                                                      Paper for treatment: landfill
# AT Paddy rice                                                             0.000000
#    Wheat                                                                  0.000078
#    Cereal grains nec                                                      0.000000
#    Vegetables, fruit, nuts                                                0.000005
#    Oil seeds                                                              0.000024
# ...                                                                            ...
# YE Membership organisation services n.e.c. (91)                           0.000000
#    Recreational, cultural and sporting services (92)                      0.000000
#    Other services (93)                                                    0.000000
#    Private households with employed persons (95)                          0.000000
#    Extra-territorial organizations and bodies                             0.000000
#
#                                                                                             \
#                                                      Plastic waste for treatment: landfill
# AT Paddy rice                                                                     0.000000
#    Wheat                                                                          0.000071
#    Cereal grains nec                                                              0.000000
#    Vegetables, fruit, nuts                                                        0.000003
#    Oil seeds                                                                      0.000022
# ...                                                                                    ...
# YE Membership organisation services n.e.c. (91)                                   0.000000
#    Recreational, cultural and sporting services (92)                              0.000000
#    Other services (93)                                                            0.000000
#    Private households with employed persons (95)                                  0.000000
#    Extra-territorial organizations and bodies                                     0.000000
#
#                                                                                                           \
#                                                      Inert/metal/hazardous waste for treatment: landfill
# AT Paddy rice                                                                                  0.000000
#    Wheat                                                                                       0.000078
#    Cereal grains nec                                                                           0.000000
#    Vegetables, fruit, nuts                                                                     0.000005
#    Oil seeds                                                                                   0.000024
# ...                                                                                                 ...
# YE Membership organisation services n.e.c. (91)                                                0.000000
#    Recreational, cultural and sporting services (92)                                           0.000000
#    Other services (93)                                                                         0.000000
#    Private households with employed persons (95)                                               0.000000
#    Extra-territorial organizations and bodies                                                  0.000000
#
#                                                                                              \
#                                                      Textiles waste for treatment: landfill
# AT Paddy rice                                                                      0.000000
#    Wheat                                                                           0.000085
#    Cereal grains nec                                                               0.000000
#    Vegetables, fruit, nuts                                                         0.000004
#    Oil seeds                                                                       0.000038
# ...                                                                                     ...
# YE Membership organisation services n.e.c. (91)                                    0.000000
#    Recreational, cultural and sporting services (92)                               0.000000
#    Other services (93)                                                             0.000000
#    Private households with employed persons (95)                                   0.000000
#    Extra-territorial organizations and bodies                                      0.000000
#
#                                                                                          \
#                                                      Wood waste for treatment: landfill
# AT Paddy rice                                                                  0.000000
#    Wheat                                                                       0.000082
#    Cereal grains nec                                                           0.000000
#    Vegetables, fruit, nuts                                                     0.000004
#    Oil seeds                                                                   0.000032
# ...                                                                                 ...
# YE Membership organisation services n.e.c. (91)                                0.000000
#    Recreational, cultural and sporting services (92)                           0.000000
#    Other services (93)                                                         0.000000
#    Private households with employed persons (95)                               0.000000
#    Extra-territorial organizations and bodies                                  0.000000
#
#                                                                                                    \
#                                                      Membership organisation services n.e.c. (91)
# AT Paddy rice                                                                            0.000000
#    Wheat                                                                                 0.000114
#    Cereal grains nec                                                                     0.000000
#    Vegetables, fruit, nuts                                                               0.000004
#    Oil seeds                                                                             0.000019
# ...                                                                                           ...
# YE Membership organisation services n.e.c. (91)                                          0.000000
#    Recreational, cultural and sporting services (92)                                     0.000000
#    Other services (93)                                                                   0.000000
#    Private households with employed persons (95)                                         0.000000
#    Extra-territorial organizations and bodies                                            0.000000
#
#                                                                                                         \
#                                                      Recreational, cultural and sporting services (92)
# AT Paddy rice                                                                                 0.000000
#    Wheat                                                                                      0.000121
#    Cereal grains nec                                                                          0.000000
#    Vegetables, fruit, nuts                                                                    0.000009
#    Oil seeds                                                                                  0.000038
# ...                                                                                                ...
# YE Membership organisation services n.e.c. (91)                                               0.000000
#    Recreational, cultural and sporting services (92)                                          0.000000
#    Other services (93)                                                                        0.000000
#    Private households with employed persons (95)                                              0.000000
#    Extra-territorial organizations and bodies                                                 0.000000
#
#                                                                           \
#                                                      Other services (93)
# AT Paddy rice                                                   0.000000
#    Wheat                                                        0.000102
#    Cereal grains nec                                            0.000000
#    Vegetables, fruit, nuts                                      0.000005
#    Oil seeds                                                    0.000024
# ...                                                                  ...
# YE Membership organisation services n.e.c. (91)                 0.000000
#    Recreational, cultural and sporting services (92)            0.000000
#    Other services (93)                                          0.000000
#    Private households with employed persons (95)                0.000000
#    Extra-territorial organizations and bodies                   0.000000
#
#                                                                                                     \
#                                                      Private households with employed persons (95)
# AT Paddy rice                                                                             0.000000
#    Wheat                                                                                  0.000083
#    Cereal grains nec                                                                      0.000000
#    Vegetables, fruit, nuts                                                                0.000005
#    Oil seeds                                                                              0.000027
# ...                                                                                            ...
# YE Membership organisation services n.e.c. (91)                                           0.000000
#    Recreational, cultural and sporting services (92)                                      0.000000
#    Other services (93)                                                                    0.000000
#    Private households with employed persons (95)                                          0.000000
#    Extra-territorial organizations and bodies                                             0.000000
#
#
#                                                      Extra-territorial organizations and bodies
# AT Paddy rice                                                                               NaN
#    Wheat                                                                                    NaN
#    Cereal grains nec                                                                        NaN
#    Vegetables, fruit, nuts                                                                  NaN
#    Oil seeds                                                                                NaN
# ...                                                                                         ...
# YE Membership organisation services n.e.c. (91)                                             NaN
#    Recreational, cultural and sporting services (92)                                        NaN
#    Other services (93)                                                                      NaN
#    Private households with employed persons (95)                                            NaN
#    Extra-territorial organizations and bodies                                               NaN
#
# [45800 rows x 9800 columns]

# %% [markdown]
# ## Calculate DR factor
# Calculate the impact factors of the driver for each impact region i driven by consumption in region j product sector k.
#
# These impact factors tell how
#
# To calculate DR factor:
# 1. Calculate the monetary impact factor impact/€ from 2019 exiobase data
# 2. Multiply each column of DR unit with the impact factors of consumption region j in product sector k. The resulting matrix represents the distribution of impacts of 1€ consumption in each consumption region.

# %%
# calculate the monetary impact factors from exiobase 2019 data
groups = exio3_11.satellite.get_index(
    as_dict=True,
    grouping_pattern={
        "Cropland - Cereal grains nec Cropland": "Land stress - annual and permanent",
        "Crops nec": "Land stress - annual and permanent",
        "Cropland - Oil seeds": "Land stress - annual and permanent",
        "Cropland - Paddy rice": "Land stress - annual and permanent",
        "Cropland - Plant-based fibers": "Land stress - annual and permanent",
        "Cropland - Sugar cane, sugar beet": "Land stress - annual and permanent",
        "Cropland - Vegetables, fruit, nuts": "Land stress - annual and permanent",
        "Cropland - Wheat": "Land stress - annual and permanent",
    }
)

exio3_19.satellite_agg = exio3_19.satellite.copy(new_name="Aggregated land stress - annual and permanent")

for df_name, df in zip(exio3_19.satellite_agg.get_DataFrame(data=False, with_unit=True, with_population=False),
exio3_19.satellite_agg.get_DataFrame(data=True, with_unit=True, with_population=False)):
    if df_name == "unit":
        exio3_19.satellite_agg.__dict__[df_name] = df.groupby(groups).apply(lambda x: " & ".join(x.unit.unique()))
    else:
        exio3_19.satellite_agg.__dict__[df_name] = df.groupby(groups).sum()

exio_19_diag = exio3_19.satellite_agg.diag_stressor(("Land stress - annual and permanent"))
exio3_19.exio_19_diag = exio_19_diag
exio3_19.calc_all()
# Out:
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:956: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   F_Y_agg = self.F_Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:900: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   Y_agg = Y.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:984: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_cba.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:993: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_pba.groupby(level="region", axis=1, sort=False).sum()
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:1001: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_imp_reg = self.D_imp.groupby(
# /nix/store/7wbnyr3241jd0p97l6db02skmsc7cy8z-python3.12-pymrio/lib/python3.12/site-packages/pymrio/core/mriosystem.py:1007: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   self.D_exp_reg = self.D_exp.groupby(

# %%
# use 2019 impact factors for calculating dr_f
# calculate dr_f - share of the driver of biodiversity loss in impact region i from the total amount of the driver that is driven by consumption in consumption region j, product sector k

dr_f = dr_u.copy()
blue_water_total = exio3_19.satellite_agg.M.loc["Land stress - annual and permanent"]
scalars = blue_water_total.to_numpy() # multipliers for each column
print(len(scalars)) # 9800
print(dr_u.shape) # 37000 (impact region-sector pairs) * 9800 (consumption region-sector pairs)

# multiply each column of dr_u by the respective column value from exio3_19.satellite_agg.M
dr_f = dr_f * scalars # same as dr_f * diag(scalars) but more efficient with numpy broadcasting
dr_f
# Out:
# 9800
# (45800, 9800)
#                                                              AT            \
#                                                      Paddy rice     Wheat
# AT Paddy rice                                               0.0  0.000000
#    Wheat                                                    0.0  1.481481
#    Cereal grains nec                                        0.0  0.000000
#    Vegetables, fruit, nuts                                  0.0  0.000003
#    Oil seeds                                                0.0  0.000015
# ...                                                         ...       ...
# YE Membership organisation services n.e.c. (91)             0.0  0.000000
#    Recreational, cultural and sporting services (92)        0.0  0.000000
#    Other services (93)                                      0.0  0.000000
#    Private households with employed persons (95)            0.0  0.000000
#    Extra-territorial organizations and bodies               0.0  0.000000
#
#                                                                         \
#                                                      Cereal grains nec
# AT Paddy rice                                                 0.000000
#    Wheat                                                      0.000024
#    Cereal grains nec                                          0.000000
#    Vegetables, fruit, nuts                                    0.000002
#    Oil seeds                                                  0.000009
# ...                                                                ...
# YE Membership organisation services n.e.c. (91)               0.000000
#    Recreational, cultural and sporting services (92)          0.000000
#    Other services (93)                                        0.000000
#    Private households with employed persons (95)              0.000000
#    Extra-territorial organizations and bodies                 0.000000
#
#                                                                               \
#                                                      Vegetables, fruit, nuts
# AT Paddy rice                                                       0.000000
#    Wheat                                                            0.000060
#    Cereal grains nec                                                0.000000
#    Vegetables, fruit, nuts                                          0.278254
#    Oil seeds                                                        0.000018
# ...                                                                      ...
# YE Membership organisation services n.e.c. (91)                     0.000000
#    Recreational, cultural and sporting services (92)                0.000000
#    Other services (93)                                              0.000000
#    Private households with employed persons (95)                    0.000000
#    Extra-territorial organizations and bodies                       0.000000
#
#                                                                 \
#                                                      Oil seeds
# AT Paddy rice                                         0.000000
#    Wheat                                              0.000013
#    Cereal grains nec                                  0.000000
#    Vegetables, fruit, nuts                            0.000001
#    Oil seeds                                          0.085444
# ...                                                        ...
# YE Membership organisation services n.e.c. (91)       0.000000
#    Recreational, cultural and sporting services (92)  0.000000
#    Other services (93)                                0.000000
#    Private households with employed persons (95)      0.000000
#    Extra-territorial organizations and bodies         0.000000
#
#                                                                              \
#                                                      Sugar cane, sugar beet
# AT Paddy rice                                                      0.000000
#    Wheat                                                           0.000138
#    Cereal grains nec                                               0.000000
#    Vegetables, fruit, nuts                                         0.000012
#    Oil seeds                                                       0.000045
# ...                                                                     ...
# YE Membership organisation services n.e.c. (91)                    0.000000
#    Recreational, cultural and sporting services (92)               0.000000
#    Other services (93)                                             0.000000
#    Private households with employed persons (95)                   0.000000
#    Extra-territorial organizations and bodies                      0.000000
#
#                                                                          \
#                                                      Plant-based fibers
# AT Paddy rice                                              0.000000e+00
#    Wheat                                                   4.063787e-06
#    Cereal grains nec                                       0.000000e+00
#    Vegetables, fruit, nuts                                 4.827560e-07
#    Oil seeds                                               2.173159e-06
# ...                                                                 ...
# YE Membership organisation services n.e.c. (91)            0.000000e+00
#    Recreational, cultural and sporting services (92)       0.000000e+00
#    Other services (93)                                     0.000000e+00
#    Private households with employed persons (95)           0.000000e+00
#    Extra-territorial organizations and bodies              0.000000e+00
#
#                                                                               \
#                                                          Crops nec    Cattle
# AT Paddy rice                                         0.000000e+00  0.000000
#    Wheat                                              3.352550e-06  0.004478
#    Cereal grains nec                                  0.000000e+00  0.000000
#    Vegetables, fruit, nuts                            4.117940e-07  0.000318
#    Oil seeds                                          2.236399e-06  0.000385
# ...                                                            ...       ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00  0.000000
#    Recreational, cultural and sporting services (92)  0.000000e+00  0.000000
#    Other services (93)                                0.000000e+00  0.000000
#    Private households with employed persons (95)      0.000000e+00  0.000000
#    Extra-territorial organizations and bodies         0.000000e+00  0.000000
#
#                                                                 ...  \
#                                                           Pigs  ...
# AT Paddy rice                                         0.000000  ...
#    Wheat                                              0.027477  ...
#    Cereal grains nec                                  0.000000  ...
#    Vegetables, fruit, nuts                            0.002032  ...
#    Oil seeds                                          0.001434  ...
# ...                                                        ...  ...
# YE Membership organisation services n.e.c. (91)       0.000000  ...
#    Recreational, cultural and sporting services (92)  0.000000  ...
#    Other services (93)                                0.000000  ...
#    Private households with employed persons (95)      0.000000  ...
#    Extra-territorial organizations and bodies         0.000000  ...
#
#                                                                                 WM  \
#                                                      Paper for treatment: landfill
# AT Paddy rice                                                             0.000000
#    Wheat                                                                  0.000043
#    Cereal grains nec                                                      0.000000
#    Vegetables, fruit, nuts                                                0.000003
#    Oil seeds                                                              0.000013
# ...                                                                            ...
# YE Membership organisation services n.e.c. (91)                           0.000000
#    Recreational, cultural and sporting services (92)                      0.000000
#    Other services (93)                                                    0.000000
#    Private households with employed persons (95)                          0.000000
#    Extra-territorial organizations and bodies                             0.000000
#
#                                                                                             \
#                                                      Plastic waste for treatment: landfill
# AT Paddy rice                                                                     0.000000
#    Wheat                                                                          0.000044
#    Cereal grains nec                                                              0.000000
#    Vegetables, fruit, nuts                                                        0.000002
#    Oil seeds                                                                      0.000014
# ...                                                                                    ...
# YE Membership organisation services n.e.c. (91)                                   0.000000
#    Recreational, cultural and sporting services (92)                              0.000000
#    Other services (93)                                                            0.000000
#    Private households with employed persons (95)                                  0.000000
#    Extra-territorial organizations and bodies                                     0.000000
#
#                                                                                                           \
#                                                      Inert/metal/hazardous waste for treatment: landfill
# AT Paddy rice                                                                                  0.000000
#    Wheat                                                                                       0.000040
#    Cereal grains nec                                                                           0.000000
#    Vegetables, fruit, nuts                                                                     0.000003
#    Oil seeds                                                                                   0.000013
# ...                                                                                                 ...
# YE Membership organisation services n.e.c. (91)                                                0.000000
#    Recreational, cultural and sporting services (92)                                           0.000000
#    Other services (93)                                                                         0.000000
#    Private households with employed persons (95)                                               0.000000
#    Extra-territorial organizations and bodies                                                  0.000000
#
#                                                                                              \
#                                                      Textiles waste for treatment: landfill
# AT Paddy rice                                                                      0.000000
#    Wheat                                                                           0.000031
#    Cereal grains nec                                                               0.000000
#    Vegetables, fruit, nuts                                                         0.000001
#    Oil seeds                                                                       0.000014
# ...                                                                                     ...
# YE Membership organisation services n.e.c. (91)                                    0.000000
#    Recreational, cultural and sporting services (92)                               0.000000
#    Other services (93)                                                             0.000000
#    Private households with employed persons (95)                                   0.000000
#    Extra-territorial organizations and bodies                                      0.000000
#
#                                                                                          \
#                                                      Wood waste for treatment: landfill
# AT Paddy rice                                                                  0.000000
#    Wheat                                                                       0.000034
#    Cereal grains nec                                                           0.000000
#    Vegetables, fruit, nuts                                                     0.000002
#    Oil seeds                                                                   0.000013
# ...                                                                                 ...
# YE Membership organisation services n.e.c. (91)                                0.000000
#    Recreational, cultural and sporting services (92)                           0.000000
#    Other services (93)                                                         0.000000
#    Private households with employed persons (95)                               0.000000
#    Extra-territorial organizations and bodies                                  0.000000
#
#                                                                                                    \
#                                                      Membership organisation services n.e.c. (91)
# AT Paddy rice                                                                        0.000000e+00
#    Wheat                                                                             1.139859e-05
#    Cereal grains nec                                                                 0.000000e+00
#    Vegetables, fruit, nuts                                                           3.974076e-07
#    Oil seeds                                                                         1.885202e-06
# ...                                                                                           ...
# YE Membership organisation services n.e.c. (91)                                      0.000000e+00
#    Recreational, cultural and sporting services (92)                                 0.000000e+00
#    Other services (93)                                                               0.000000e+00
#    Private households with employed persons (95)                                     0.000000e+00
#    Extra-territorial organizations and bodies                                        0.000000e+00
#
#                                                                                                         \
#                                                      Recreational, cultural and sporting services (92)
# AT Paddy rice                                                                                 0.000000
#    Wheat                                                                                      0.000019
#    Cereal grains nec                                                                          0.000000
#    Vegetables, fruit, nuts                                                                    0.000001
#    Oil seeds                                                                                  0.000006
# ...                                                                                                ...
# YE Membership organisation services n.e.c. (91)                                               0.000000
#    Recreational, cultural and sporting services (92)                                          0.000000
#    Other services (93)                                                                        0.000000
#    Private households with employed persons (95)                                              0.000000
#    Extra-territorial organizations and bodies                                                 0.000000
#
#                                                                           \
#                                                      Other services (93)
# AT Paddy rice                                                   0.000000
#    Wheat                                                        0.000024
#    Cereal grains nec                                            0.000000
#    Vegetables, fruit, nuts                                      0.000001
#    Oil seeds                                                    0.000006
# ...                                                                  ...
# YE Membership organisation services n.e.c. (91)                 0.000000
#    Recreational, cultural and sporting services (92)            0.000000
#    Other services (93)                                          0.000000
#    Private households with employed persons (95)                0.000000
#    Extra-territorial organizations and bodies                   0.000000
#
#                                                                                                     \
#                                                      Private households with employed persons (95)
# AT Paddy rice                                                                         0.000000e+00
#    Wheat                                                                              8.553789e-06
#    Cereal grains nec                                                                  0.000000e+00
#    Vegetables, fruit, nuts                                                            4.947870e-07
#    Oil seeds                                                                          2.749205e-06
# ...                                                                                            ...
# YE Membership organisation services n.e.c. (91)                                       0.000000e+00
#    Recreational, cultural and sporting services (92)                                  0.000000e+00
#    Other services (93)                                                                0.000000e+00
#    Private households with employed persons (95)                                      0.000000e+00
#    Extra-territorial organizations and bodies                                         0.000000e+00
#
#
#                                                      Extra-territorial organizations and bodies
# AT Paddy rice                                                                               NaN
#    Wheat                                                                                    NaN
#    Cereal grains nec                                                                        NaN
#    Vegetables, fruit, nuts                                                                  NaN
#    Oil seeds                                                                                NaN
# ...                                                                                         ...
# YE Membership organisation services n.e.c. (91)                                             NaN
#    Recreational, cultural and sporting services (92)                                        NaN
#    Other services (93)                                                                      NaN
#    Private households with employed persons (95)                                            NaN
#    Extra-territorial organizations and bodies                                               NaN
#
# [45800 rows x 9800 columns]

# %% [markdown]
# ## Calculate BDe factors (PDF/€ for each consumption region and product sector)
#
# 1. Multiply each cell of dr_u with the CF (characterisation factor from lc-impact) of the impact region to get PDF values for every entry
# 2. Sum up columns to get the total PDF/€ for the consumption region j product sector k

# %%
# sort rows on lci in same order as dr_f.index.sortlevel
lci = lci.reindex(dr_f.index.get_level_values(0).unique())

# build array from the relevent lci stressor
# every value should be repeated 200 times (number of sectors)
cf_average = lci["Average"].to_numpy()
cf_average = np.repeat(cf_average, 200) # 1D array of length 200 * number of regions in lci
print(cf_average.shape)
# expand cf_all_effects to match the shape of dr_f
cf_average = np.tile(cf_average, (dr_f.shape[1], 1)).T
print(cf_average.shape)

pdf = dr_f * cf_average
pdf
# Out:
# (45800,)
# (45800, 9800)
#                                                              AT                \
#                                                      Paddy rice         Wheat
# AT Paddy rice                                               0.0  0.000000e+00
#    Wheat                                                    0.0  2.267412e-15
#    Cereal grains nec                                        0.0  0.000000e+00
#    Vegetables, fruit, nuts                                  0.0  4.739137e-21
#    Oil seeds                                                0.0  2.299792e-20
# ...                                                         ...           ...
# YE Membership organisation services n.e.c. (91)             0.0  0.000000e+00
#    Recreational, cultural and sporting services (92)        0.0  0.000000e+00
#    Other services (93)                                      0.0  0.000000e+00
#    Private households with employed persons (95)            0.0  0.000000e+00
#    Extra-territorial organizations and bodies               0.0  0.000000e+00
#
#                                                                         \
#                                                      Cereal grains nec
# AT Paddy rice                                             0.000000e+00
#    Wheat                                                  3.748517e-20
#    Cereal grains nec                                      0.000000e+00
#    Vegetables, fruit, nuts                                3.345552e-21
#    Oil seeds                                              1.372240e-20
# ...                                                                ...
# YE Membership organisation services n.e.c. (91)           0.000000e+00
#    Recreational, cultural and sporting services (92)      0.000000e+00
#    Other services (93)                                    0.000000e+00
#    Private households with employed persons (95)          0.000000e+00
#    Extra-territorial organizations and bodies             0.000000e+00
#
#                                                                               \
#                                                      Vegetables, fruit, nuts
# AT Paddy rice                                                   0.000000e+00
#    Wheat                                                        9.195566e-20
#    Cereal grains nec                                            0.000000e+00
#    Vegetables, fruit, nuts                                      4.258689e-16
#    Oil seeds                                                    2.715872e-20
# ...                                                                      ...
# YE Membership organisation services n.e.c. (91)                 0.000000e+00
#    Recreational, cultural and sporting services (92)            0.000000e+00
#    Other services (93)                                          0.000000e+00
#    Private households with employed persons (95)                0.000000e+00
#    Extra-territorial organizations and bodies                   0.000000e+00
#
#                                                                     \
#                                                          Oil seeds
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              2.024253e-20
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            1.663510e-21
#    Oil seeds                                          1.307727e-16
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                              \
#                                                      Sugar cane, sugar beet
# AT Paddy rice                                                  0.000000e+00
#    Wheat                                                       2.114184e-19
#    Cereal grains nec                                           0.000000e+00
#    Vegetables, fruit, nuts                                     1.764743e-20
#    Oil seeds                                                   6.846672e-20
# ...                                                                     ...
# YE Membership organisation services n.e.c. (91)                0.000000e+00
#    Recreational, cultural and sporting services (92)           0.000000e+00
#    Other services (93)                                         0.000000e+00
#    Private households with employed persons (95)               0.000000e+00
#    Extra-territorial organizations and bodies                  0.000000e+00
#
#                                                                          \
#                                                      Plant-based fibers
# AT Paddy rice                                              0.000000e+00
#    Wheat                                                   6.219642e-21
#    Cereal grains nec                                       0.000000e+00
#    Vegetables, fruit, nuts                                 7.388600e-22
#    Oil seeds                                               3.326028e-21
# ...                                                                 ...
# YE Membership organisation services n.e.c. (91)            0.000000e+00
#    Recreational, cultural and sporting services (92)       0.000000e+00
#    Other services (93)                                     0.000000e+00
#    Private households with employed persons (95)           0.000000e+00
#    Extra-territorial organizations and bodies              0.000000e+00
#
#                                                                     \
#                                                          Crops nec
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              5.131091e-21
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            6.302524e-22
#    Oil seeds                                          3.422818e-21
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                     \
#                                                             Cattle
# AT Paddy rice                                         0.000000e+00
#    Wheat                                              6.853337e-18
#    Cereal grains nec                                  0.000000e+00
#    Vegetables, fruit, nuts                            4.862748e-19
#    Oil seeds                                          5.892108e-19
# ...                                                            ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00
#    Recreational, cultural and sporting services (92)  0.000000e+00
#    Other services (93)                                0.000000e+00
#    Private households with employed persons (95)      0.000000e+00
#    Extra-territorial organizations and bodies         0.000000e+00
#
#                                                                     ...  \
#                                                               Pigs  ...
# AT Paddy rice                                         0.000000e+00  ...
#    Wheat                                              4.205347e-17  ...
#    Cereal grains nec                                  0.000000e+00  ...
#    Vegetables, fruit, nuts                            3.109292e-18  ...
#    Oil seeds                                          2.195295e-18  ...
# ...                                                            ...  ...
# YE Membership organisation services n.e.c. (91)       0.000000e+00  ...
#    Recreational, cultural and sporting services (92)  0.000000e+00  ...
#    Other services (93)                                0.000000e+00  ...
#    Private households with employed persons (95)      0.000000e+00  ...
#    Extra-territorial organizations and bodies         0.000000e+00  ...
#
#                                                                                 WM  \
#                                                      Paper for treatment: landfill
# AT Paddy rice                                                         0.000000e+00
#    Wheat                                                              6.633277e-20
#    Cereal grains nec                                                  0.000000e+00
#    Vegetables, fruit, nuts                                            4.274393e-21
#    Oil seeds                                                          2.026573e-20
# ...                                                                            ...
# YE Membership organisation services n.e.c. (91)                       0.000000e+00
#    Recreational, cultural and sporting services (92)                  0.000000e+00
#    Other services (93)                                                0.000000e+00
#    Private households with employed persons (95)                      0.000000e+00
#    Extra-territorial organizations and bodies                         0.000000e+00
#
#                                                                                             \
#                                                      Plastic waste for treatment: landfill
# AT Paddy rice                                                                 0.000000e+00
#    Wheat                                                                      6.680076e-20
#    Cereal grains nec                                                          0.000000e+00
#    Vegetables, fruit, nuts                                                    2.944816e-21
#    Oil seeds                                                                  2.113206e-20
# ...                                                                                    ...
# YE Membership organisation services n.e.c. (91)                               0.000000e+00
#    Recreational, cultural and sporting services (92)                          0.000000e+00
#    Other services (93)                                                        0.000000e+00
#    Private households with employed persons (95)                              0.000000e+00
#    Extra-territorial organizations and bodies                                 0.000000e+00
#
#                                                                                                           \
#                                                      Inert/metal/hazardous waste for treatment: landfill
# AT Paddy rice                                                                              0.000000e+00
#    Wheat                                                                                   6.112624e-20
#    Cereal grains nec                                                                       0.000000e+00
#    Vegetables, fruit, nuts                                                                 4.076428e-21
#    Oil seeds                                                                               1.915905e-20
# ...                                                                                                 ...
# YE Membership organisation services n.e.c. (91)                                            0.000000e+00
#    Recreational, cultural and sporting services (92)                                       0.000000e+00
#    Other services (93)                                                                     0.000000e+00
#    Private households with employed persons (95)                                           0.000000e+00
#    Extra-territorial organizations and bodies                                              0.000000e+00
#
#                                                                                              \
#                                                      Textiles waste for treatment: landfill
# AT Paddy rice                                                                  0.000000e+00
#    Wheat                                                                       4.669027e-20
#    Cereal grains nec                                                           0.000000e+00
#    Vegetables, fruit, nuts                                                     2.212688e-21
#    Oil seeds                                                                   2.085965e-20
# ...                                                                                     ...
# YE Membership organisation services n.e.c. (91)                                0.000000e+00
#    Recreational, cultural and sporting services (92)                           0.000000e+00
#    Other services (93)                                                         0.000000e+00
#    Private households with employed persons (95)                               0.000000e+00
#    Extra-territorial organizations and bodies                                  0.000000e+00
#
#                                                                                          \
#                                                      Wood waste for treatment: landfill
# AT Paddy rice                                                              0.000000e+00
#    Wheat                                                                   5.136549e-20
#    Cereal grains nec                                                       0.000000e+00
#    Vegetables, fruit, nuts                                                 2.510980e-21
#    Oil seeds                                                               2.040608e-20
# ...                                                                                 ...
# YE Membership organisation services n.e.c. (91)                            0.000000e+00
#    Recreational, cultural and sporting services (92)                       0.000000e+00
#    Other services (93)                                                     0.000000e+00
#    Private households with employed persons (95)                           0.000000e+00
#    Extra-territorial organizations and bodies                              0.000000e+00
#
#                                                                                                    \
#                                                      Membership organisation services n.e.c. (91)
# AT Paddy rice                                                                        0.000000e+00
#    Wheat                                                                             1.744558e-20
#    Cereal grains nec                                                                 0.000000e+00
#    Vegetables, fruit, nuts                                                           6.082339e-22
#    Oil seeds                                                                         2.885309e-21
# ...                                                                                           ...
# YE Membership organisation services n.e.c. (91)                                      0.000000e+00
#    Recreational, cultural and sporting services (92)                                 0.000000e+00
#    Other services (93)                                                               0.000000e+00
#    Private households with employed persons (95)                                     0.000000e+00
#    Extra-territorial organizations and bodies                                        0.000000e+00
#
#                                                                                                         \
#                                                      Recreational, cultural and sporting services (92)
# AT Paddy rice                                                                             0.000000e+00
#    Wheat                                                                                  2.951534e-20
#    Cereal grains nec                                                                      0.000000e+00
#    Vegetables, fruit, nuts                                                                2.150872e-21
#    Oil seeds                                                                              9.180260e-21
# ...                                                                                                ...
# YE Membership organisation services n.e.c. (91)                                           0.000000e+00
#    Recreational, cultural and sporting services (92)                                      0.000000e+00
#    Other services (93)                                                                    0.000000e+00
#    Private households with employed persons (95)                                          0.000000e+00
#    Extra-territorial organizations and bodies                                             0.000000e+00
#
#                                                                           \
#                                                      Other services (93)
# AT Paddy rice                                               0.000000e+00
#    Wheat                                                    3.666139e-20
#    Cereal grains nec                                        0.000000e+00
#    Vegetables, fruit, nuts                                  1.846328e-21
#    Oil seeds                                                8.569551e-21
# ...                                                                  ...
# YE Membership organisation services n.e.c. (91)             0.000000e+00
#    Recreational, cultural and sporting services (92)        0.000000e+00
#    Other services (93)                                      0.000000e+00
#    Private households with employed persons (95)            0.000000e+00
#    Extra-territorial organizations and bodies               0.000000e+00
#
#                                                                                                     \
#                                                      Private households with employed persons (95)
# AT Paddy rice                                                                         0.000000e+00
#    Wheat                                                                              1.309161e-20
#    Cereal grains nec                                                                  0.000000e+00
#    Vegetables, fruit, nuts                                                            7.572735e-22
#    Oil seeds                                                                          4.207669e-21
# ...                                                                                            ...
# YE Membership organisation services n.e.c. (91)                                       0.000000e+00
#    Recreational, cultural and sporting services (92)                                  0.000000e+00
#    Other services (93)                                                                0.000000e+00
#    Private households with employed persons (95)                                      0.000000e+00
#    Extra-territorial organizations and bodies                                         0.000000e+00
#
#
#                                                      Extra-territorial organizations and bodies
# AT Paddy rice                                                                               NaN
#    Wheat                                                                                    NaN
#    Cereal grains nec                                                                        NaN
#    Vegetables, fruit, nuts                                                                  NaN
#    Oil seeds                                                                                NaN
# ...                                                                                         ...
# YE Membership organisation services n.e.c. (91)                                             NaN
#    Recreational, cultural and sporting services (92)                                        NaN
#    Other services (93)                                                                      NaN
#    Private households with employed persons (95)                                            NaN
#    Extra-territorial organizations and bodies                                               NaN
#
# [45800 rows x 9800 columns]

# %%
# sum up all columns to get the total impact for each region-sector pair
pdf_total = pdf.sum()
pdf_total
# Out:
# AT  Paddy rice                                           0.000000e+00
#     Wheat                                                1.256852e-14
#     Cereal grains nec                                    7.898491e-17
#     Vegetables, fruit, nuts                              5.426828e-15
#     Oil seeds                                            1.318648e-14
#                                                              ...
# WM  Membership organisation services n.e.c. (91)         2.850509e-16
#     Recreational, cultural and sporting services (92)    5.130785e-16
#     Other services (93)                                  7.991411e-16
#     Private households with employed persons (95)        2.998189e-16
#     Extra-territorial organizations and bodies           0.000000e+00
# Length: 9800, dtype: float64
